# %%
import os
import sys
import pandas as pd
from bs4 import BeautifulSoup
   
folder = os.listdir('Routes')

   
# empty list
data = []
path = 'Routes/AJJtoRU.html'
# for getting the header from
# the HTML file
soup = BeautifulSoup(open(path),'html.parser')
header = soup.find_all("table")
# print(len(header))
header2 = header[1].find_all("tr")
for i in header2:
    temp = i.find_all("td")
    l = []
    for s in temp:
        k= " ".join((s.get_text()).split())
        l.append(k)
    data.append(l)
data.pop(1)
data.pop(0)

for i in data:
    i.pop(0)


  
# for items in header2:
#     try:
#         list_header.append(items.get_text())
#     except:
#         continue
  
# # for getting the data 
# HTML_data = soup.find_all("table").find_all("td")[1:]
# print(header2[0])

# print()
# print("end of html")
# print()
  
# for element in HTML_data:
#     sub_data = ""
# #     print(element)
# #     break
#     for sub_element in element:
# #         print(sub_element.name)
# #         break
#         try:
#             sub_data+=(sub_element.get_text())
#         except:
#             continue
#     l = sub_data.split()      
#     data.append(l)
    
# print(data[0])
  
# Storing the data into Pandas
# DataFrame 
dataFrame = pd.DataFrame(data = data)
   
# Converting Pandas DataFrame
# into CSV file
dataFrame.to_csv('AJJtoRU.csv')
# /Users/adity/Desktop/railwaysim/html.ipynb
# /Users/adity/Desktop/railwaysim/Routes/AJJtoRU.html
# Routes/AJJtoRU.html

# %%
import os
import sys
import pandas as pd
from bs4 import BeautifulSoup
   
folder = os.listdir('Routes')
folder.sort()
folder.pop(0)

j=0
for s in folder:
    i = s.index('.')
    j = j+1
    ans = s[0:i]
    k = ans.find('to')

    s1 = ans[0:k]
    s2 = ans[k+2:]

    print(s1,end=",")
    print(s2)

    # print(ans , end=" ")
    # print(j)

    # data = []
    # path = 'Routes/'
    # path = path +s
    # # for getting the header from
    # # the HTML file
    # soup = BeautifulSoup(open(path),'html.parser')
    # header = soup.find_all("table")
    # # print(len(header))
    # header2 = header[1].find_all("tr")
    # for i in header2:
    #     temp = i.find_all("td")
    #     l = []
    #     for s in temp:
    #         k= " ".join((s.get_text()).split())
    #         l.append(k)
    #     data.append(l)
    # data.pop(1)
    # data.pop(0)

    # for i in data:
    #     i.pop(0)

    # dataFrame = pd.DataFrame(data = data)

    # dataFrame.to_csv(ans)
# Out:
# AJJ,RU
# AJJ,TI
# CGL,AJJ
# CGL,CJ
# CGL,VM
# CJ,AJJ
# CTRE,MCN
# CTRE,WJR
# ELR,GDR
# HC,TI
# KOK,TNP
# KPD,JTJ
# MCN,SVUR
# MCPT,VLCY
# MPK,TBM
# NPKM,ELR
# PER,VLK
# TBM,CGL
# TNP,TVT
# TVT,ENR
# VLK,ANNG
# VLK,AVD
# VPY,PER
